# %% [markdown]
# # Classification Task dengan Decision Tree

# %% [markdown]
# Konsep Dasar
#
# Terminology : root node, internal node, leaf node
# ![image.png](attachment:image.png)
#
# Algoritma Desicion Tree :
# * Classification and Regression Tree
# * ID3
# * C4.5
# * C5.0

# %% [markdown]
# ## Gini Impurity
#
# metrik yang digunakan dalam algoritma pohon keputusan untuk mengukur probabilitas elemen yang dipilih secara acak diberi label yang salah.
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Information Gain
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Membangun Desicion Tree
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Dataset

# %%
from sklearn.datasets import load_iris

X, y = load_iris(return_X_y=True)

print(f'Dimensi Feature: {X.shape}')
print(f'Class: {set(y)}')
# Out:
# Dimensi Feature: (150, 4)
# Class: {np.int64(0), np.int64(1), np.int64(2)}

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    test_size=0.3,
                                                    random_state=42)

# %% [markdown]
# # Classification Dengan Desicion Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier(max_depth=4)

model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=4)

# %% [markdown]
# ## Visualisasi Model

# %%
import matplotlib.pyplot as plt
from sklearn import tree

plt.rcParams['figure.dpi'] = 85
plt.subplots(figsize=(10, 10))
tree.plot_tree(model, fontsize=10)
plt.show()

# %% [markdown]
# # Evaluasi Model

# %%
from sklearn.metrics import classification_report

y_pred = model.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      1.00      1.00        13
#            2       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45
